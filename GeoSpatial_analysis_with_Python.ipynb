# %%
pip install welly
# Out:
# Collecting welly
#   Downloading welly-0.5.2-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.2/79.2 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from welly) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from welly) (1.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from welly) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from welly) (3.7.1)
# Collecting lasio (from welly)
#   Downloading lasio-0.31-py2.py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 kB 4.1 MB/s eta 0:00:00
# Collecting striplog (from welly)
#   Downloading striplog-0.9.2-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from welly) (4.66.1)
# Collecting wellpathpy (from welly)
#   Downloading wellpathpy-0.5.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from welly) (2.31.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->welly) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->welly) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->welly) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->welly) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->welly) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->welly) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->welly) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->welly) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->welly) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->welly) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->welly) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->welly) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->welly) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->welly) (1.16.0)
# Installing collected packages: wellpathpy, lasio, striplog, welly
# Successfully installed lasio-0.31 striplog-0.9.2 wellpathpy-0.5.0 welly-0.5.2

# %%
pip install geopandas
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.0)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2023.7.22)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.23.5)

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
municipality = gpd.read_file('/content/municipality.shp')

# %%
municipality_geojson = gpd.read_file('/content/municipality.geojson')

# %%
#reading metadata
len(municipality)
# Out:
# 775

# %%
municipality.head()
# Out:
#    PROVINCE        PR_NAME   DISTRICT           PALIKA        TYPE  \
# 0         1  Province No 1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika
# 1         1  Province No 1  TAPLEJUNG       Maiwakhola  Gaunpalika
# 2         1  Province No 1  TAPLEJUNG        Meringden  Gaunpalika
# 3         1  Province No 1  TAPLEJUNG       Mikwakhola  Gaunpalika
# 4         1  Province No 1  TAPLEJUNG     Phaktanglung  Gaunpalika
#
#                                             geometry
# 0  POLYGON ((87.60985 27.37043, 87.61107 27.36943...
# 1  POLYGON ((87.50402 27.42901, 87.50672 27.42831...
# 2  POLYGON ((87.51233 27.56818, 87.51196 27.56768...
# 3  POLYGON ((87.66620 27.73004, 87.66659 27.73000...
# 4  POLYGON ((87.83673 27.95137, 87.83735 27.95119...

# %%
municipality.geom_type
# Out:
# 0      Polygon
# 1      Polygon
# 2      Polygon
# 3      Polygon
# 4      Polygon
#         ...
# 770    Polygon
# 771    Polygon
# 772    Polygon
# 773    Polygon
# 774    Polygon
# Length: 775, dtype: object

# %%
municipality.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
type(municipality)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
municipality.plot()
# Out:
# <Axes: >

# %%
municipality.boundary.plot()
# Out:
# <Axes: >

# %%
municipality.plot(figsize = (10,10))
# Out:
# <Axes: >

# %%
municipality.plot("PR_NAME", cmap= 'magma', legend = True)
# Out:
# <Axes: >

# %%
ax=municipality.plot("PR_NAME",cmap='magma',figsize=(15,15))
ax.set_axis_off()

# %%
abc = gpd.read_file('/content/municipality.shp')

# %%
abc.to_file('/content/municipality.shp')

# %%
abc.to_file('/content/municipality.geojson', driver = 'GeoJSON', encoding = 'utf-8')

# %%
abc.to_file('/content/municipality.gpkg', driver = 'GPKG', layer = 'palika', encoding = 'utf-8')

# %%
rupandehi = municipality[municipality['DISTRICT']=='RUPANDEHI']

# %%
rupandehi.plot()
# Out:
# <Axes: >

# %%
rupandehi.head()
# Out:
#      PROVINCE        PR_NAME   DISTRICT     PALIKA                TYPE  \
# 509         5  Province No 5  RUPANDEHI     Butwal  Upamahanagarpalika
# 510         5  Province No 5  RUPANDEHI    Devdaha         Nagarpalika
# 511         5  Province No 5  RUPANDEHI  Gaidahawa          Gaunpalika
# 512         5  Province No 5  RUPANDEHI    Kanchan          Gaunpalika
# 513         5  Province No 5  RUPANDEHI  Kotahimai          Gaunpalika
#
#                                               geometry
# 509  POLYGON ((83.39404 27.74746, 83.39444 27.74707...
# 510  POLYGON ((83.50562 27.72572, 83.50622 27.72560...
# 511  POLYGON ((83.32845 27.65126, 83.32876 27.65095...
# 512  POLYGON ((83.26076 27.69161, 83.26059 27.68940...
# 513  POLYGON ((83.33693 27.48945, 83.33803 27.48927...

# %%
len(rupandehi)
# Out:
# 17

# %%
rupandehi.plot("PALIKA",cmap='magma')
# Out:
# <Axes: >

# %%
municipality1= gpd.read_file('/content/municipality.shp')

# %%
municipality1.head()
# Out:
#    PROVINCE        PR_NAME   DISTRICT           PALIKA        TYPE  \
# 0         1  Province No 1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika
# 1         1  Province No 1  TAPLEJUNG       Maiwakhola  Gaunpalika
# 2         1  Province No 1  TAPLEJUNG        Meringden  Gaunpalika
# 3         1  Province No 1  TAPLEJUNG       Mikwakhola  Gaunpalika
# 4         1  Province No 1  TAPLEJUNG     Phaktanglung  Gaunpalika
#
#                                             geometry
# 0  POLYGON ((87.60985 27.37043, 87.61107 27.36943...
# 1  POLYGON ((87.50402 27.42901, 87.50672 27.42831...
# 2  POLYGON ((87.51233 27.56818, 87.51196 27.56768...
# 3  POLYGON ((87.66620 27.73004, 87.66659 27.73000...
# 4  POLYGON ((87.83673 27.95137, 87.83735 27.95119...

# %%
municipality1['area']=0

# %%
municipality1.head()
# Out:
#    PROVINCE        PR_NAME   DISTRICT           PALIKA        TYPE  \
# 0         1  Province No 1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika
# 1         1  Province No 1  TAPLEJUNG       Maiwakhola  Gaunpalika
# 2         1  Province No 1  TAPLEJUNG        Meringden  Gaunpalika
# 3         1  Province No 1  TAPLEJUNG       Mikwakhola  Gaunpalika
# 4         1  Province No 1  TAPLEJUNG     Phaktanglung  Gaunpalika
#
#                                             geometry  area
# 0  POLYGON ((87.60985 27.37043, 87.61107 27.36943...     0
# 1  POLYGON ((87.50402 27.42901, 87.50672 27.42831...     0
# 2  POLYGON ((87.51233 27.56818, 87.51196 27.56768...     0
# 3  POLYGON ((87.66620 27.73004, 87.66659 27.73000...     0
# 4  POLYGON ((87.83673 27.95137, 87.83735 27.95119...     0

# %%
municipality_crs = municipality1.to_crs(epsg=32645)

# %%
municipality_crs['area'] = municipality_crs.geometry.area / 10**6

# %%
municipality_crs.head()
# Out:
#    PROVINCE        PR_NAME   DISTRICT           PALIKA        TYPE  \
# 0         1  Province No 1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika
# 1         1  Province No 1  TAPLEJUNG       Maiwakhola  Gaunpalika
# 2         1  Province No 1  TAPLEJUNG        Meringden  Gaunpalika
# 3         1  Province No 1  TAPLEJUNG       Mikwakhola  Gaunpalika
# 4         1  Province No 1  TAPLEJUNG     Phaktanglung  Gaunpalika
#
#                                             geometry         area
# 0  POLYGON ((560307.153 3027612.864, 560428.320 3...    88.521700
# 1  POLYGON ((549815.446 3034054.303, 550082.592 3...   137.371061
# 2  POLYGON ((550573.020 3049473.152, 550537.274 3...   209.626709
# 3  POLYGON ((565665.744 3067475.242, 565704.431 3...   441.435863
# 4  POLYGON ((582308.234 3092096.983, 582369.345 3...  1851.420797

# %%
municipality_crs.plot('area',legend=True)
# Out:
# <Axes: >

# %%
import shapely

# %%
from shapely.geometry import Point, LineString, Polygon

# %%
#creatin a geometric object
point = Point(1,1)
line = LineString([(0,0),(5,9),(10,8)])
poly=line.buffer(1)

# %%
point
# Out:
# <POINT (1 1)>

# %%
line
# Out:
# <LINESTRING (0 0, 5 9, 10 8)>

# %%
poly
# Out:
# <POLYGON ((4.126 9.486, 4.177 9.568, 4.236 9.645, 4.302 9.716, 4.375 9.78, 4...>

# %%
point.within(poly)
# Out:
# True

# %%
point1=Point(1,7)
point1.within(poly)
# Out:
# False

# %%
poly.contains(point)
# Out:
# True

# %%
gs = gpd.GeoSeries([Point(-10,15),Point(10,2),Point(-5,16)])
gs
# Out:
# 0    POINT (-10.00000 15.00000)
# 1      POINT (10.00000 2.00000)
# 2     POINT (-5.00000 16.00000)
# dtype: geometry

# %%
gs.plot(marker="*", color ='red', markersize = 100, figsize = (4,4))
# Out:
# <Axes: >

# %%
palpa = municipality[municipality['DISTRICT']=='PALPA']

# %%
palpa.plot()
# Out:
# <Axes: >

# %%
ax = rupandehi.plot(figsize=(10,10))
palpa.plot(ax=ax)
# Out:
# <Axes: >

# %%
pip install folium matplotlib mapclassify
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Collecting mapclassify
#   Downloading mapclassify-2.6.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 778.1 kB/s eta 0:00:00
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from mapclassify) (1.2.2)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (1.5.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from mapclassify) (3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->mapclassify) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2023.7.22)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->mapclassify) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->mapclassify) (3.2.0)
# Installing collected packages: mapclassify
# Successfully installed mapclassify-2.6.0

# %%
import mapclassify
import folium
import matplotlib

# %%
rupandehi.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf3db0d2d6f15b6a740fdfee20c0cc67 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf3db0d2d6f15b6a740fdfee20c0cc67&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf3db0d2d6f15b6a740fdfee20c0cc67 = L.map(
#                 &quot;map_cf3db0d2d6f15b6a740fdfee20c0cc67&quot;,
#                 {
#                     center: [27.54897883206604, 83.42109070368656],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_cf3db0d2d6f15b6a740fdfee20c0cc67);
#
#
#
#
#
#             var tile_layer_2abeb25494446dab72ef732a934faa3d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cf3db0d2d6f15b6a740fdfee20c0cc67);
#
#
#             map_cf3db0d2d6f15b6a740fdfee20c0cc67.fitBounds(
#                 [[27.32996283160611, 83.20626251587083], [27.76799483252597, 83.63591889150229]],
#                 {}
#             );
#
#
#         function geo_json_e8acb85a94c90025e8619462d10ad27c_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_e8acb85a94c90025e8619462d10ad27c_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_e8acb85a94c90025e8619462d10ad27c_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_e8acb85a94c90025e8619462d10ad27c_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_e8acb85a94c90025e8619462d10ad27c_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_e8acb85a94c90025e8619462d10ad27c.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_e8acb85a94c90025e8619462d10ad27c_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_e8acb85a94c90025e8619462d10ad27c = L.geoJson(null, {
#                 onEachFeature: geo_json_e8acb85a94c90025e8619462d10ad27c_onEachFeature,
#
#                 style: geo_json_e8acb85a94c90025e8619462d10ad27c_styler,
#                 pointToLayer: geo_json_e8acb85a94c90025e8619462d10ad27c_pointToLayer
#         });
#
#         function geo_json_e8acb85a94c90025e8619462d10ad27c_add (data) {
#             geo_json_e8acb85a94c90025e8619462d10ad27c
#                 .addData(data)
#                 .addTo(map_cf3db0d2d6f15b6a740fdfee20c0cc67);
#         }
#             geo_json_e8acb85a94c90025e8619462d10ad27c_add({&quot;bbox&quot;: [83.20626251587083, 27.32996283160611, 83.63591889150229, 27.76799483252597], &quot;features&quot;: [{&quot;bbox&quot;: [83.36342326581052, 27.615400769635244, 83.50622426613677, 27.74867389543948], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[83.3940447037059, 27.747463083080333], [83.39444476694712, 27.74707227079415], [83.3949966415754, 27.74662789432108], [83.3953028284431, 27.746464519492918], [83.39573595476725, 27.74634233317073], [83.39591157838333, 27.746232519743955], [83.39643320479775, 27.746036207601946], [83.39652145439487, 27.745962145737735], [83.39681245408622, 27.745624958432643], [83.39699445

# %%
rupandehi.explore(column='PALIKA',cmap='magma')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42def06108aafd6bfa9d2b67bdd5e343 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend PALIKA&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;PALIKA&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#000004&#x27;&gt;&lt;/span&gt;Butwal&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#0a0822&#x27;&gt;&lt;/span&gt;Devdaha&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1d1147&#x27;&gt;&lt;/span&gt;Gaidahawa&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#36106b&#x27;&gt;&lt;/span&gt;Kanchan&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#51127c&#x27;&gt;&lt;/span&gt;Kotahimai&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#6a1c81&#x27;&gt;&lt;/span&gt;Lumbini Sanskritik&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#832681&#x27;&gt;&lt;/span&gt;Lumbini Sanskritik Development Area&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#9c2e7f&#x27;&gt;&lt;/span&gt;Marchawari&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#b73779&#x27;&gt;&lt;/span&gt;Mayadevi&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#d0416f&#x27;&gt;&lt;/span&gt;Omsatiya&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e75263&#x27;&gt;&lt;/span&gt;Rohini&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#f56b5c&#x27;&gt;&lt;/span&gt;Sainamaina&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#fc8961&#x27;&gt;&lt;/span&gt;Sammarimai&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#fea772&#x27;&gt;&lt;/span&gt;Siddharthanagar&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#fec488&#x27;&gt;&lt;/span&gt;Siyari&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#fde2a3&#x27;&gt;&lt;/span&gt;Sudhdhodhan&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#fcfdbf&#x27;&gt;&lt;/span&gt;Tillotama&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42def06108aafd6bfa9d2b67bdd5e343&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42def06108aafd6bfa9d2b67bdd5e343 = L.map(
#                 &quot;map_42def06108aafd6bfa9d2b67bdd5e343&quot;,
#                 {
#                     center: [27.54897883206604, 83.42109070368656],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_42def06108aafd6bfa9d2b67bdd5e343);
#
#
#
#
#
#             var tile_layer_88e3c6d13cea48f5173db543f6d99188 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&q
